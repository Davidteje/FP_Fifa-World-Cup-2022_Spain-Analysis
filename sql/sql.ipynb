# %% [markdown]
# ### PROYECTO: FP_Fifa-World-Cup-2022_Spain-Analysis
# ### JUPYTER NOTEBOOK: sql
# ### FECHA: Diciembre 2022

# %% [markdown]
# ### En este Jupyter Notebook se realizan las siguientes tareas:
# #### - ETL del proyecto
# #### - Importación de los eventos de las tablas de 'Players', 'Teams', 'Matches', 'Events' y 'Métricas' (estas 2 últimas están limpias y transformadas en el Jupyter Notebook 'main', realizando su limpieza y transformación.
# #### - Carga de Tablas en SQL con sqlalchemy. Las relaciones entre tablas se han creado en MyWorkbench para que sea una base de datos relacional.
# #### - Ejecución de algunas queries SQL para comprobar su correcto funcionamiento.
# #### - Exportación para su posterior carga en la visualización Tableau

# %%
# importación de librerías
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Importación y limpieza tabla 'Players'

# %%
df_pl=pd.read_excel(r'C:\Users\david\OneDrive\Documentos\DATA ANALYTICS\Proyectos\Github\FP_Fifa-World-Cup-2022_Spain-Analysis\data\FWC 2022 - Player IDs_221208.xlsx')
df_pl.head()
# Out:
#    CompetitionId  TeamIfesId    TeamName TeamDelegateFunction  \
# 0         255711       43901  Costa Rica               Player
# 1         255711       43901  Costa Rica               Player
# 2         255711       43901  Costa Rica               Player
# 3         255711       43901  Costa Rica               Player
# 4         255711       43901  Costa Rica               Player
#
#    TeamDelegateIfesId  PlayerShirtNumber PlayerPosition  \
# 0              199175                  1     Goalkeeper
# 1              405824                  2     Midfielder
# 2              411350                  3       Defender
# 3              439979                  4       Defender
# 4              236530                  5     Midfielder
#
#   TeamDelegatePopularName TeamDelegateDisplayName TeamDelegateFirstName(s)  \
# 0            NAVAS Keylor            Keylor NAVAS           Keilor Antonio
# 1           CHACON Daniel           Daniel CHACON            Daniel Alonso
# 2       VARGAS Juan Pablo       Juan Pablo VARGAS               Juan Pablo
# 3          FULLER Keysher          Keysher FULLER                  Keysher
# 4            BORGES Celso            Celso BORGES                    Celso
#
#   TeamDelegateLastName(s) TeamDelegateGender TeamDelegateDateofBirth  \
# 0            NAVAS GAMBOA               Male              1986-12-15
# 1            CHACÓN SALAS               Male              2001-04-11
# 2           VARGAS CAMPOS               Male              1995-06-06
# 3           FULLER SPENCE               Male              1994-07-12
# 4             BORGES MORA               Male              1988-05-27
#
#   TeamDelegateFifaNationalityCountryCode
# 0                                    CRC
# 1                                    CRC
# 2                                    CRC
# 3                                    CRC
# 4                                    CRC

# %%
df_pl.shape
# Out:
# (130, 14)

# %%
df_pl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130 entries, 0 to 129
# Data columns (total 14 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   CompetitionId                           130 non-null    int64
#  1   TeamIfesId                              130 non-null    int64
#  2   TeamName                                130 non-null    object
#  3   TeamDelegateFunction                    130 non-null    object
#  4   TeamDelegateIfesId                      130 non-null    int64
#  5   PlayerShirtNumber                       130 non-null    int64
#  6   PlayerPosition                          130 non-null    object
#  7   TeamDelegatePopularName                 130 non-null    object
#  8   TeamDelegateDisplayName                 130 non-null    object
#  9   TeamDelegateFirstName(s)                130 non-null    object
#  10  TeamDelegateLastName(s)                 130 non-null    object
#  11  TeamDelegateGender                      130 non-null    object
#  12  TeamDelegateDateofBirth                 130 non-null    datetime64[ns]
#  13  TeamDelegateFifaNationalityCountryCode  130 non-null    object
# dtypes: datetime64[ns](1), int64(4), object(9)
# memory usage: 14.3+ KB

# %%
df_pl = df_pl.drop(['TeamDelegateFunction', 'TeamDelegatePopularName', 'TeamDelegateGender'], axis=1)
df_pl.head()
# Out:
#    CompetitionId  TeamIfesId    TeamName  TeamDelegateIfesId  \
# 0         255711       43901  Costa Rica              199175
# 1         255711       43901  Costa Rica              405824
# 2         255711       43901  Costa Rica              411350
# 3         255711       43901  Costa Rica              439979
# 4         255711       43901  Costa Rica              236530
#
#    PlayerShirtNumber PlayerPosition TeamDelegateDisplayName  \
# 0                  1     Goalkeeper            Keylor NAVAS
# 1                  2     Midfielder           Daniel CHACON
# 2                  3       Defender       Juan Pablo VARGAS
# 3                  4       Defender          Keysher FULLER
# 4                  5     Midfielder            Celso BORGES
#
#   TeamDelegateFirstName(s) TeamDelegateLastName(s) TeamDelegateDateofBirth  \
# 0           Keilor Antonio            NAVAS GAMBOA              1986-12-15
# 1            Daniel Alonso            CHACÓN SALAS              2001-04-11
# 2               Juan Pablo           VARGAS CAMPOS              1995-06-06
# 3                  Keysher           FULLER SPENCE              1994-07-12
# 4                    Celso             BORGES MORA              1988-05-27
#
#   TeamDelegateFifaNationalityCountryCode
# 0                                    CRC
# 1                                    CRC
# 2                                    CRC
# 3                                    CRC
# 4                                    CRC

# %%
df_pl = df_pl.rename(columns={'CompetitionId':'competition_id','TeamIfesId':'team_id', 'TeamName':'team', \
'TeamDelegateIfesId' : 'player_id', 'PlayerShirtNumber':'player_shirt_number','PlayerPosition':'player_position', \
'TeamDelegateDisplayName':'player_name', 'TeamDelegateFirstName(s)':'player_first_name', \
'TeamDelegateLastName(s)':'player_last_name', 'TeamDelegateDateofBirth': 'player_date_birth', \
'TeamDelegateFifaNationalityCountryCode': 'team_code'})
df_pl.head()
# Out:
#    competition_id  team_id        team  player_id  player_shirt_number  \
# 0          255711    43901  Costa Rica     199175                    1
# 1          255711    43901  Costa Rica     405824                    2
# 2          255711    43901  Costa Rica     411350                    3
# 3          255711    43901  Costa Rica     439979                    4
# 4          255711    43901  Costa Rica     236530                    5
#
#   player_position        player_name player_first_name player_last_name  \
# 0      Goalkeeper       Keylor NAVAS    Keilor Antonio     NAVAS GAMBOA
# 1      Midfielder      Daniel CHACON     Daniel Alonso     CHACÓN SALAS
# 2        Defender  Juan Pablo VARGAS        Juan Pablo    VARGAS CAMPOS
# 3        Defender     Keysher FULLER           Keysher    FULLER SPENCE
# 4      Midfielder       Celso BORGES             Celso      BORGES MORA
#
#   player_date_birth team_code
# 0        1986-12-15       CRC
# 1        2001-04-11       CRC
# 2        1995-06-06       CRC
# 3        1994-07-12       CRC
# 4        1988-05-27       CRC

# %%
df_pl.player_position = df_pl.player_position.apply(lambda x : x.lower())
df_pl.head()
# Out:
#    competition_id  team_id        team  player_id  player_shirt_number  \
# 0          255711    43901  Costa Rica     199175                    1
# 1          255711    43901  Costa Rica     405824                    2
# 2          255711    43901  Costa Rica     411350                    3
# 3          255711    43901  Costa Rica     439979                    4
# 4          255711    43901  Costa Rica     236530                    5
#
#   player_position        player_name player_first_name player_last_name  \
# 0      goalkeeper       Keylor NAVAS    Keilor Antonio     NAVAS GAMBOA
# 1      midfielder      Daniel CHACON     Daniel Alonso     CHACÓN SALAS
# 2        defender  Juan Pablo VARGAS        Juan Pablo    VARGAS CAMPOS
# 3        defender     Keysher FULLER           Keysher    FULLER SPENCE
# 4      midfielder       Celso BORGES             Celso      BORGES MORA
#
#   player_date_birth team_code
# 0        1986-12-15       CRC
# 1        2001-04-11       CRC
# 2        1995-06-06       CRC
# 3        1994-07-12       CRC
# 4        1988-05-27       CRC

# %% [markdown]
# ### Importación y limpieza tabla 'Teams'

# %%
df_te=pd.read_excel(r'C:\Users\david\OneDrive\Documentos\DATA ANALYTICS\Proyectos\Github\FP_Fifa-World-Cup-2022_Spain-Analysis\data\FWC 2022 - Team IDs_221208.xlsx')
df_te.head()
# Out:
#    Team_id              Team   Team_Name Team_Code
# 0    43901  Costa Rica (CRC)  Costa Rica       CRC
# 1    43948     Germany (GER)     Germany       GER
# 2    43819       Japan (JPN)       Japan       JPN
# 3    43872     Morocco (MAR)     Morocco       MAR
# 4    43969       Spain (ESP)       Spain       ESP

# %%
df_te = df_te.drop(['Team'], axis=1)
df_te.head()
# Out:
#    Team_id   Team_Name Team_Code
# 0    43901  Costa Rica       CRC
# 1    43948     Germany       GER
# 2    43819       Japan       JPN
# 3    43872     Morocco       MAR
# 4    43969       Spain       ESP

# %%
df_te.columns= df_te.columns.str.lower()
df_te.head()
# Out:
#    team_id   team_name team_code
# 0    43901  Costa Rica       CRC
# 1    43948     Germany       GER
# 2    43819       Japan       JPN
# 3    43872     Morocco       MAR
# 4    43969       Spain       ESP

# %% [markdown]
# ### Importación y limpieza tabla 'Matches'

# %%
df_ma=pd.read_excel(r'C:\Users\david\OneDrive\Documentos\DATA ANALYTICS\Proyectos\Github\FP_Fifa-World-Cup-2022_Spain-Analysis\data\FWC 2022 - Match IDs_221208.xlsx')
df_ma.head()
# Out:
#   Match Date  Match Status  not A-Match  Unnamed: 3  Kick-off  No.  \
# 0 2022-11-20           NaN          NaN         NaN      1900    1
# 1 2022-11-21           NaN          NaN         NaN      1600    3
# 2 2022-11-21           NaN          NaN         NaN      1900    2
# 3 2022-11-21           NaN          NaN         NaN      2200    4
# 4 2022-11-22           NaN          NaN         NaN      1300    8
#
#              Competition Name              Venue City  \
# 0  FIFA World Cup Qatar 2022™           AL KHOR (QAT)
# 1  FIFA World Cup Qatar 2022™         AL RAYYAN (QAT)
# 2  FIFA World Cup Qatar 2022™  DOHA (AD-DAWHAH) (QAT)
# 3  FIFA World Cup Qatar 2022™         AL RAYYAN (QAT)
# 4  FIFA World Cup Qatar 2022™         AL DAAYEN (QAT)
#
#                          Stadium     Team A        Team B  90  90.1  HT  HT.1  \
# 0                Al Bayt Stadium      Qatar       Ecuador NaN   NaN NaN   NaN
# 1  Khalifa International Stadium    England       IR Iran NaN   NaN NaN   NaN
# 2             Al Thumama Stadium    Senegal   Netherlands NaN   NaN NaN   NaN
# 3          Ahmad Bin Ali Stadium        USA         Wales NaN   NaN NaN   NaN
# 4                 Lusail Stadium  Argentina  Saudi Arabia NaN   NaN NaN   NaN
#
#    ET  ET.1  PK  PK.1  FR A  FR B Classification    Group  Attendance  Note  \
# 0 NaN   NaN NaN   NaN   NaN   NaN            FWC  Group A         NaN   NaN
# 1 NaN   NaN NaN   NaN   NaN   NaN            FWC  Group B         NaN   NaN
# 2 NaN   NaN NaN   NaN   NaN   NaN            FWC  Group A         NaN   NaN
# 3 NaN   NaN NaN   NaN   NaN   NaN            FWC  Group B         NaN   NaN
# 4 NaN   NaN NaN   NaN   NaN   NaN            FWC  Group C         NaN   NaN
#
#    Unnamed: 25  Match ID  Competition ID
# 0          NaN    128084          255711
# 1          NaN    132997          255711
# 2          NaN    132996          255711
# 3          NaN    132995          255711
# 4          NaN    133001          255711

# %%
df_ma = df_ma.drop(['Match Status', 'not A-Match', 'Unnamed: 3', 'Note', 'Unnamed: 25'], axis=1)
df_ma.head()
# Out:
#   Match Date  Kick-off  No.            Competition Name  \
# 0 2022-11-20      1900    1  FIFA World Cup Qatar 2022™
# 1 2022-11-21      1600    3  FIFA World Cup Qatar 2022™
# 2 2022-11-21      1900    2  FIFA World Cup Qatar 2022™
# 3 2022-11-21      2200    4  FIFA World Cup Qatar 2022™
# 4 2022-11-22      1300    8  FIFA World Cup Qatar 2022™
#
#                Venue City                        Stadium     Team A  \
# 0           AL KHOR (QAT)                Al Bayt Stadium      Qatar
# 1         AL RAYYAN (QAT)  Khalifa International Stadium    England
# 2  DOHA (AD-DAWHAH) (QAT)             Al Thumama Stadium    Senegal
# 3         AL RAYYAN (QAT)          Ahmad Bin Ali Stadium        USA
# 4         AL DAAYEN (QAT)                 Lusail Stadium  Argentina
#
#          Team B  90  90.1  HT  HT.1  ET  ET.1  PK  PK.1  FR A  FR B  \
# 0       Ecuador NaN   NaN NaN   NaN NaN   NaN NaN   NaN   NaN   NaN
# 1       IR Iran NaN   NaN NaN   NaN NaN   NaN NaN   NaN   NaN   NaN
# 2   Netherlands NaN   NaN NaN   NaN NaN   NaN NaN   NaN   NaN   NaN
# 3         Wales NaN   NaN NaN   NaN NaN   NaN NaN   NaN   NaN   NaN
# 4  Saudi Arabia NaN   NaN NaN   NaN NaN   NaN NaN   NaN   NaN   NaN
#
#   Classification    Group  Attendance  Match ID  Competition ID
# 0            FWC  Group A         NaN    128084          255711
# 1            FWC  Group B         NaN    132997          255711
# 2            FWC  Group A         NaN    132996          255711
# 3            FWC  Group B         NaN    132995          255711
# 4            FWC  Group C         NaN    133001          255711

# %%
df_ma = df_ma.drop(df_ma.iloc[:,8:19], axis=1)
df_ma.head()
# Out:
#   Match Date  Kick-off  No.            Competition Name  \
# 0 2022-11-20      1900    1  FIFA World Cup Qatar 2022™
# 1 2022-11-21      1600    3  FIFA World Cup Qatar 2022™
# 2 2022-11-21      1900    2  FIFA World Cup Qatar 2022™
# 3 2022-11-21      2200    4  FIFA World Cup Qatar 2022™
# 4 2022-11-22      1300    8  FIFA World Cup Qatar 2022™
#
#                Venue City                        Stadium     Team A  \
# 0           AL KHOR (QAT)                Al Bayt Stadium      Qatar
# 1         AL RAYYAN (QAT)  Khalifa International Stadium    England
# 2  DOHA (AD-DAWHAH) (QAT)             Al Thumama Stadium    Senegal
# 3         AL RAYYAN (QAT)          Ahmad Bin Ali Stadium        USA
# 4         AL DAAYEN (QAT)                 Lusail Stadium  Argentina
#
#          Team B    Group  Attendance  Match ID  Competition ID
# 0       Ecuador  Group A         NaN    128084          255711
# 1       IR Iran  Group B         NaN    132997          255711
# 2   Netherlands  Group A         NaN    132996          255711
# 3         Wales  Group B         NaN    132995          255711
# 4  Saudi Arabia  Group C         NaN    133001          255711

# %%
df_ma.columns= df_ma.columns.str.lower()
df_ma.head()
# Out:
#   match date  kick-off  no.            competition name  \
# 0 2022-11-20      1900    1  FIFA World Cup Qatar 2022™
# 1 2022-11-21      1600    3  FIFA World Cup Qatar 2022™
# 2 2022-11-21      1900    2  FIFA World Cup Qatar 2022™
# 3 2022-11-21      2200    4  FIFA World Cup Qatar 2022™
# 4 2022-11-22      1300    8  FIFA World Cup Qatar 2022™
#
#                venue city                        stadium     team a  \
# 0           AL KHOR (QAT)                Al Bayt Stadium      Qatar
# 1         AL RAYYAN (QAT)  Khalifa International Stadium    England
# 2  DOHA (AD-DAWHAH) (QAT)             Al Thumama Stadium    Senegal
# 3         AL RAYYAN (QAT)          Ahmad Bin Ali Stadium        USA
# 4         AL DAAYEN (QAT)                 Lusail Stadium  Argentina
#
#          team b    group  attendance  match id  competition id
# 0       Ecuador  Group A         NaN    128084          255711
# 1       IR Iran  Group B         NaN    132997          255711
# 2   Netherlands  Group A         NaN    132996          255711
# 3         Wales  Group B         NaN    132995          255711
# 4  Saudi Arabia  Group C         NaN    133001          255711

# %%
df_ma.columns
# Out:
# Index(['match date', 'kick-off', 'no.', 'competition name', 'venue city',
#        'stadium', 'team a', 'team b', 'group', 'attendance', 'match id',
#        'competition id'],
#       dtype='object')

# %%
df_ma = df_ma.rename(columns={'match date':'match_date','kick-off':'match_time', 'no.':'match_number', \
'competition name' : 'competition_name', 'venue city':'city','team a':'team_1', \
'team b':'team_2', 'match id':'match_id', 'competition id':'competition_id'})

# %%
df_ma.group[:48] = df_ma.group[:48].apply(lambda x : x[-1])
df_ma.head()
# Out:
#   match_date  match_time  match_number            competition_name  \
# 0 2022-11-20        1900             1  FIFA World Cup Qatar 2022™
# 1 2022-11-21        1600             3  FIFA World Cup Qatar 2022™
# 2 2022-11-21        1900             2  FIFA World Cup Qatar 2022™
# 3 2022-11-21        2200             4  FIFA World Cup Qatar 2022™
# 4 2022-11-22        1300             8  FIFA World Cup Qatar 2022™
#
#                      city                        stadium     team_1  \
# 0           AL KHOR (QAT)                Al Bayt Stadium      Qatar
# 1         AL RAYYAN (QAT)  Khalifa International Stadium    England
# 2  DOHA (AD-DAWHAH) (QAT)             Al Thumama Stadium    Senegal
# 3         AL RAYYAN (QAT)          Ahmad Bin Ali Stadium        USA
# 4         AL DAAYEN (QAT)                 Lusail Stadium  Argentina
#
#          team_2 group  attendance  match_id  competition_id
# 0       Ecuador     A         NaN    128084          255711
# 1       IR Iran     B         NaN    132997          255711
# 2   Netherlands     A         NaN    132996          255711
# 3         Wales     B         NaN    132995          255711
# 4  Saudi Arabia     C         NaN    133001          255711

# %% [markdown]
# ### Importación de tablas 'Events' y 'Métricas' para su carga en SQL

# %%
df_ev = pd.read_excel(r'C:\Users\david\OneDrive\Documentos\DATA ANALYTICS\Proyectos\Github\FP_Fifa-World-Cup-2022_Spain-Analysis\viz\ficheros Tableau\tabla_eventos.xlsx')
df_ev.head()
# Out:
#    match_id  match_run_time_in_ms match_run_time  match_time_in_ms  event_id  \
# 0    133004                     0       00:00:00                 0         1
# 1    133004                     0       00:00:00                 0         2
# 2    133004                  1480       00:00:02              1480         3
# 3    133004                  1480       00:00:02              1480         4
# 4    133004                  1519       00:00:02              1519         5
#
#    player_seq_id  event_order  half_time side       category  \
# 0              1            1          1  NaN  in_possession
# 1              1            2          1  NaN  in_possession
# 2              2            1          1    r  in_possession
# 3              2            2          1    r  in_possession
# 4              1            3          1    r  in_possession
#
#                 event            event_type action_type  from_player_id  \
# 0             kickoff         start_restart         NaN          447866
# 1                pass          distribution         NaN          447866
# 2            no_offer   offering_to_receive         NaN          335999
# 3           reception  receiving_possession     kickoff          335999
# 4  possession_outcome    possession_outcome         NaN          447866
#
#   from_player_name  from_player_shirt_number  to_player_id   to_player_name  \
# 0             GAVI                         9           NaN              NaN
# 1             GAVI                         9      335999.0  AYMERIC LAPORTE
# 2  AYMERIC LAPORTE                        24           NaN              NaN
# 3  AYMERIC LAPORTE                        24           NaN              NaN
# 4             GAVI                         9           NaN              NaN
#
#    to_player_shirt_number  team_id team_name sequence_type  \
# 0                     NaN    43969     SPAIN           NaN
# 1                    24.0    43969     SPAIN           NaN
# 2                     NaN    43969     SPAIN           NaN
# 3                     NaN    43969     SPAIN           NaN
# 4                     NaN    43969     SPAIN    possession
#
#                outcome outcome_additional opposition_touch   body_type  \
# 0                  NaN                NaN              NaN         NaN
# 1  possession_complete                NaN              NaN  right_foot
# 2                  NaN                NaN              NaN         NaN
# 3                  NaN                NaN              NaN         NaN
# 4  possession_complete                NaN              NaN         NaN
#
#   direction     pressure style style_additional frame_location game_state  \
# 0       NaN          NaN   NaN              NaN            NaN        NaN
# 1       NaN  no_pressure  push              NaN            NaN        NaN
# 2       NaN          NaN   NaN              NaN            NaN        NaN
# 3       NaN  no_pressure   NaN              NaN            NaN        NaN
# 4       NaN          NaN   NaN              NaN            NaN        NaN
#
#   origin origin_additional save_type save_detail stance  x_frame  y_frame  \
# 0    NaN               NaN       NaN         NaN    NaN      NaN      NaN
# 1    NaN               NaN       NaN         NaN    NaN      NaN      NaN
# 2    NaN               NaN       NaN         NaN    NaN      NaN      NaN
# 3    NaN               NaN       NaN         NaN    NaN      NaN      NaN
# 4    NaN               NaN       NaN         NaN    NaN      NaN      NaN
#
#       movement  offering_to_receive_total_units line_break_direction  \
# 0          NaN                              NaN                  NaN
# 1          NaN                              NaN                  NaN
# 2  no_movement                              3.0                  NaN
# 3          NaN                              NaN                  NaN
# 4          NaN                              NaN                  NaN
#
#   line_break_outcome team_shape team_unit team_units_broken  total_team_units  \
# 0                NaN        NaN       NaN               NaN               NaN
# 1      no_line_break        NaN       NaN               NaN               NaN
# 2                NaN        NaN       NaN               NaN               NaN
# 3                NaN     inside  in_front               NaN               3.0
# 4                NaN        NaN       NaN               NaN               NaN
#
#    event_end_time_in_ms         x  x_mirrored         y  y_mirrored  \
# 0                   NaN  0.499810    0.499810  0.503971    0.503971
# 1                   NaN  0.499810    0.499810  0.503971    0.503971
# 2                1480.0  0.691905    0.308095  0.428824    0.571176
# 3                   NaN  0.691905    0.308095  0.428824    0.571176
# 4                   NaN  0.690286    0.309714  0.433382    0.566618
#
#    x_location_start  x_location_start_mirrored  x_location_end  \
# 0               NaN                        NaN             NaN
# 1           0.49981                    0.49981        0.690286
# 2               NaN                        NaN             NaN
# 3               NaN                        NaN             NaN
# 4               NaN                        NaN             NaN
#
#    x_location_end_mirrored  y_location_start  y_location_start_mirrored  \
# 0                      NaN               NaN                        NaN
# 1                 0.309714          0.503971                   0.503971
# 2                      NaN               NaN                        NaN
# 3                      NaN               NaN                        NaN
# 4                      NaN               NaN                        NaN
#
#    y_location_end  y_location_end_mirrored  match_time_in_min
# 0             NaN                      NaN                  0
# 1        0.433382                 0.566618                  0
# 2             NaN                      NaN                  0
# 3             NaN                      NaN                  0
# 4             NaN                      NaN                  0

# %%
df_est = pd.read_excel(r'C:\Users\david\OneDrive\Documentos\DATA ANALYTICS\Proyectos\Github\FP_Fifa-World-Cup-2022_Spain-Analysis\viz\ficheros Tableau\tabla_metricas.xlsx')
df_est
# Out:
#    match_id        team  corners  faltas_lanzadas  faltas_directas_lanzadas  \
# 0    133004       SPAIN        5               18                        12
# 1    133004  COSTA RICA        0               11                         8
# 2    133021       SPAIN        6               16                        14
# 3    133021     GERMANY        5               15                        13
# 4    133035       SPAIN        2               11                         9
# 5    133035       JAPAN        0                8                         6
# 6    128074       SPAIN        8               20                        14
# 7    128074     MOROCCO        0               18                        14
#
#    faltas_realizadas  penaltis  penaltis_marcados %_acierto_penaltis  \
# 0                 11         1                  1                100
# 1                 18         0                  0               none
# 2                 15         0                  0               none
# 3                 16         0                  0               none
# 4                  8         0                  0               none
# 5                 11         0                  0               none
# 6                 18         3                  0                  0
# 7                 20         4                  3                 75
#
#    saques_banda  saques_banda_recepcionados  %_acierto_sb  ofrecimientos  \
# 0            24                          24         100.0           1677
# 1            13                          11          84.6            409
# 2            23                          21          91.3           1040
# 3            15                           8          53.3            670
# 4            22                          20          90.9           1747
# 5            11                          10          90.9            437
# 6            33                          33         100.0           1621
# 7            29                          21          72.4            613
#
#    ofrecimientos_con_movimiento  ofrecimientos_con_movimiento_camp_contr  \
# 0                          1085                                      694
# 1                           250                                      103
# 2                           633                                      282
# 3                           440                                      209
# 4                          1138                                      825
# 5                           315                                      123
# 6                           896                                      779
# 7                           438                                      163
#
#    ofrecimientos_con_movimiento_ult_terc  remates_totales  remates_totales_fa  \
# 0                                    309               17                   3
# 1                                     43                0                   0
# 2                                    112                7                   2
# 3                                    107               10                   3
# 4                                    451               14                   7
# 5                                     56                6                   2
# 6                                    446               16                   3
# 7                                     71               10                   3
#
#    remates_on_target  remates_on_target_fa  remates_off_target  \
# 0                  7                     0                   8
# 1                  0                     0                   8
# 2                  3                     1                   2
# 3                  4                     0                   2
# 4                  5                     1                   2
# 5                  3                     1                   2
# 6                  3                     0                   6
# 7                  7                     1                   6
#
#    %_remates_on_target  goles  goles_fa  %_gol/on_target  goles_concedidos  \
# 0                 41.2      7         0            100.0                 0
# 1                  0.0      0         0              0.0                 7
# 2                 42.9      1         0             33.3                 1
# 3                 40.0      1         0             25.0                 1
# 4                 35.7      1         0             20.0                 2
# 5                 50.0      2         1             66.7                 1
# 6                 18.8      0         0              0.0                 0
# 7                 70.0      0         0             42.9                 0
#
#    centros_totales  centros_completados  asistencias_centro  pases  \
# 0               17                    2                   2   1037
# 1                5                    0                   0    218
# 2                9                    2                   1    624
# 3               13                    1                   0    337
# 4               20                    2                   0   1048
# 5                6                    3                   1    214
# 6               27                    4                   0   1008
# 7               10                    4                   0    294
#
#    pases_completados  %_acierto_pases  pases_completados_linebreak  \
# 0                976             94.1                          193
# 1                159             72.9                           43
# 2                542             86.9                          118
# 3                270             80.1                           63
# 4                969             92.5                          126
# 5                155             72.4                           45
# 6                932             92.5                          126
# 7                207             70.4                           62
#
#    asistencias_pase  cambios_de_juego  pases_ultimo_tercio  \
# 0                 2                 8                  203
# 1                 0                 1                   21
# 2                 0                 9                   69
# 3                 0                 2                   53
# 4                 1                 8                  244
# 5                 1                 2                   29
# 6                 0                 8                  196
# 7                 0                 4                   29
#
#    pases_completados_ultimo_tercio  progresiones  intentos_regate  \
# 0                              180            42               11
# 1                               16             9                4
# 2                               55            31               11
# 3                               30            30                9
# 4                              218            25               10
# 5                               26            10                4
# 6                              167            26               13
# 7                               18            21               11
#
#    intentos_regate_ult_terc  regates_completados  \
# 0                         9                    2
# 1                         2                    2
# 2                         5                    1
# 3                         4                    4
# 4                         6                    6
# 5                         2                    2
# 6                         8                    4
# 7                         3                    4
#
#    regates_completados_ult_terc  recepciones  recep_behind  recep_3_4  \
# 0                             2         1092            23          0
# 1                             1          226             1          1
# 2                             0          666            16          3
# 3                             1          379             9          2
# 4                             3         1092            17          0
# 5                             1          237            10          0
# 6                             1         1075            27          0
# 7                             0          330            10          4
#
#    recep_2_3  recep_1_2  recep_inside  %_recep_inside  recep_outside  \
# 0         60        307           628            57.5            464
# 1         23         74           139            61.5             87
# 2         47        186           362            54.4            304
# 3         34        132           246            64.9            133
# 4         18        193           674            61.7            418
# 5         21         75           159            67.1             78
# 6         26        165           697            64.8            378
# 7         25        136           202            61.2            128
#
#    %_recep_outside  recep_ultimo_tercio  bloqueos  despejes  intercepciones  \
# 0             42.5                  232        16        10               4
# 1             38.5                   31        21        30               8
# 2             45.6                   92        24        28               6
# 3             35.1                   82        32        24               8
# 4             38.3                  282         7        15              11
# 5             32.9                   44        39        39              10
# 6             35.2                  245        19        26               7
# 7             38.8                   51        32        56               9
#
#    entradas_totales  entradas_exitosas  %_entradas_exitosas  take_on_against  \
# 0                18                  7                 38.9                4
# 1                42                 13                 31.0               11
# 2                40                 13                 32.5                9
# 3                45                 14                 31.1               11
# 4                16                  8                 50.0                4
# 5                29                  6                 20.7               10
# 6                41                  5                 12.2               11
# 7                52                 15                 28.8               13
#
#    pushing-on  presiones  presiones_directas  %_presion_directa  \
# 0         208        185                  50               27.0
# 1         795        585                  47                8.0
# 2         316        275                  45               16.4
# 3         508        387                  59               15.2
# 4         173        150                  25               16.7
# 5         791        637                  62                9.7
# 6         222        217                  56               25.8
# 7         599        573                  75               13.1
#
#    gk_active_eng  gk_aerial_control  gk_def_support  gk_goalprevention_tot  \
# 0              3                  1               1                      0
# 1              7                  0               7                     17
# 2              5                  4               3                     11
# 3              3                  0               2                      7
# 4              1                  0               1                      6
# 5              3                  1               1                     14
# 6              1                  1               0                     10
# 7              4                  3               1                     17
#
#    gk_goalprevention_tot_saved  duelos_totales  duelos_totales_ganados  \
# 0                            0              37                      19
# 1                           10              37                      18
# 2                            9              33                      16
# 3                            6              36                      18
# 4                            4              30                      13
# 5                           13              30                      17
# 6                            6              47                      23
# 7                           17              49                      23
#
#    %_duelos_totales_ganados  duelos_campo_ganados  duelos_físicos_ganados  \
# 0                        51                     6                       2
# 1                        49                     1                       1
# 2                        48                     6                       1
# 3                        50                     8                       1
# 4                        43                     3                       0
# 5                        57                     4                       1
# 6                        49                     4                       2
# 7                        47                     3                       5
#
#    duelos_aereos_ganados  sustituciones  posesion  posesión_disputa  \
# 0                     11              5     78.81              1.96
# 1                     16              5     19.23              1.96
# 2                      9              4     60.23              2.17
# 3                      9              5     37.60              2.17
# 4                     10              5     78.95              1.58
# 5                     12              5     19.47              1.58
# 6                     17              6     71.35              2.31
# 7                     15              6     26.34              2.31
#
#    pases_verticales  pases_adelante  pases_atras  pases_horizontales  \
# 0                87             153          136                 687
# 1                22              37           27                  95
# 2                53              98           88                 356
# 3                35              59           42                 169
# 4                59             123          123                 723
# 5                27              44           20                  91
# 6                96             142           79                 711
# 7                35              57           37                 113
#
#    %_pases_verticales  %_pases_adelante  %_pases_atras  %_pases_horizontales  \
# 0                   9                16             14                    70
# 1                  14                23             17                    60
# 2                  10                18             16                    66
# 3                  13                22             16                    63
# 4                   6                13             13                    75
# 5                  17                28             13                    59
# 6                  10                15              8                    76
# 7                  17                28             18                    55
#
#    recuperaciones  recuperaciones_campo_contr  %_recuperaciones_campo_contr  \
# 0              38                          18                            47
# 1              38                           7                            18
# 2              47                          13                            28
# 3              48                          15                            31
# 4              35                          11                            31
# 5              34                           4                            12
# 6              33                          12                            36
# 7              51                           3                             6
#
#    recuperaciones_campo_prop  %_recuperaciones_campo_prop  recuperaciones1  \
# 0                         20                           53               47
# 1                         31                           82               39
# 2                         34                           72               50
# 3                         33                           69               53
# 4                         24                           69               35
# 5                         30                           88               34
# 6                         21                           64               36
# 7                         48                           94               59
#
#    recuperaciones_campo_contr1  %_recuperaciones_campo_contr1  \
# 0                           20                             43
# 1                            7                             18
# 2                           15                             30
# 3                           16                             30
# 4                           11                             31
# 5                            4                             12
# 6                           13                             36
# 7                            5                              8
#
#    recuperaciones_campo_prop1  %_recuperaciones_campo_prop1  perdidas  \
# 0                          27                            57       116
# 1                          32                            82       104
# 2                          35                            70       139
# 3                          37                            70       128
# 4                          24                            69       128
# 5                          30                            88        91
# 6                          23                            64       166
# 7                          54                            92       149
#
#    perdidas_campo_prop  %_perdidas_campo_prop  tarj_amarillas  tarjetas_rojas  \
# 0                   26                     22               0               0
# 1                   42                     40               2               0
# 2                   62                     45               1               0
# 3                   32                     25               3               0
# 4                   19                     15               0               0
# 5                   34                     37               3               0
# 6                   16                     10               1               0
# 7                   58                     39               1               0
#
#    asistencias_totales   xG  distancia_recorrida_km  n_speed_runs_(15-20km/h)  \
# 0                    4  3.5               122.43399                      1331
# 1                    0  0.0               116.61037                      1455
# 2                    1  0.6               112.65189                      1461
# 3                    0  1.3               115.54569                      1559
# 4                    1  1.4               114.04544                      1326
# 5                    2  1.0               116.00564                      1333
# 6                    0  0.7               142.64314                      1450
# 7                    0  1.0               147.78556                      1533
#
#    n_of_sprints_(>20km/h)  total_average_speed_(km/h)
# 0                     548                    6.720440
# 1                     453                    6.505847
# 2                     557                    6.504642
# 3                     617                    6.681131
# 4                     459                    6.558801
# 5                     493                    6.866877
# 6                     636                    6.147745
# 7                     614                    6.100761

# %% [markdown]
# ### CONEXIÓN A SQL Y CREACIÓN DE BBDD

# %%
#pip install PyMySQL
# Out:
# Requirement already satisfied: PyMySQL in c:\users\david\software\lib\site-packages (1.0.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import mysql.connector as conn
from sqlalchemy import create_engine

# %%
with open('contraseñas.txt', 'r') as file:
    pass_=file.readlines()[0]

# %%
str_conn=f'mysql+pymysql://root:{pass_}@localhost:3306' #Conectar al servidor
cursor=create_engine(str_conn) #Cursor que apunta al servidor

# %%
#cursor.execute('drop database if exists worldxxxxxxcup_qatar_22;')

# %%
#cursor.execute('create database fifa_worldcup_2022;')

# %%
str_conn=f'mysql+pymysql://root:{pass_}@localhost:3306/fifa_worldcup_2022'
cursor=create_engine(str_conn)

# %%
df_pl.head()
# Out:
#    competition_id  team_id        team  player_id  player_shirt_number  \
# 0          255711    43901  Costa Rica     199175                    1
# 1          255711    43901  Costa Rica     405824                    2
# 2          255711    43901  Costa Rica     411350                    3
# 3          255711    43901  Costa Rica     439979                    4
# 4          255711    43901  Costa Rica     236530                    5
#
#   player_position        player_name player_first_name player_last_name  \
# 0      goalkeeper       Keylor NAVAS    Keilor Antonio     NAVAS GAMBOA
# 1      midfielder      Daniel CHACON     Daniel Alonso     CHACÓN SALAS
# 2        defender  Juan Pablo VARGAS        Juan Pablo    VARGAS CAMPOS
# 3        defender     Keysher FULLER           Keysher    FULLER SPENCE
# 4      midfielder       Celso BORGES             Celso      BORGES MORA
#
#   player_date_birth team_code
# 0        1986-12-15       CRC
# 1        2001-04-11       CRC
# 2        1995-06-06       CRC
# 3        1994-07-12       CRC
# 4        1988-05-27       CRC

# %%
df_te.head()
# Out:
#    team_id   team_name team_code
# 0    43901  Costa Rica       CRC
# 1    43948     Germany       GER
# 2    43819       Japan       JPN
# 3    43872     Morocco       MAR
# 4    43969       Spain       ESP

# %%
df_ma.head()
# Out:
#   match_date  match_time  match_number            competition_name  \
# 0 2022-11-20        1900             1  FIFA World Cup Qatar 2022™
# 1 2022-11-21        1600             3  FIFA World Cup Qatar 2022™
# 2 2022-11-21        1900             2  FIFA World Cup Qatar 2022™
# 3 2022-11-21        2200             4  FIFA World Cup Qatar 2022™
# 4 2022-11-22        1300             8  FIFA World Cup Qatar 2022™
#
#                      city                        stadium     team_1  \
# 0           AL KHOR (QAT)                Al Bayt Stadium      Qatar
# 1         AL RAYYAN (QAT)  Khalifa International Stadium    England
# 2  DOHA (AD-DAWHAH) (QAT)             Al Thumama Stadium    Senegal
# 3         AL RAYYAN (QAT)          Ahmad Bin Ali Stadium        USA
# 4         AL DAAYEN (QAT)                 Lusail Stadium  Argentina
#
#          team_2 group  attendance  match_id  competition_id
# 0       Ecuador     A         NaN    128084          255711
# 1       IR Iran     B         NaN    132997          255711
# 2   Netherlands     A         NaN    132996          255711
# 3         Wales     B         NaN    132995          255711
# 4  Saudi Arabia     C         NaN    133001          255711

# %%
df_ev.head()
# Out:
#    match_id  match_run_time_in_ms match_run_time  match_time_in_ms  event_id  \
# 0    133004                     0       00:00:00                 0         1
# 1    133004                     0       00:00:00                 0         2
# 2    133004                  1480       00:00:02              1480         3
# 3    133004                  1480       00:00:02              1480         4
# 4    133004                  1519       00:00:02              1519         5
#
#    player_seq_id  event_order  half_time side       category  \
# 0              1            1          1  NaN  in_possession
# 1              1            2          1  NaN  in_possession
# 2              2            1          1    r  in_possession
# 3              2            2          1    r  in_possession
# 4              1            3          1    r  in_possession
#
#                 event            event_type action_type  from_player_id  \
# 0             kickoff         start_restart         NaN          447866
# 1                pass          distribution         NaN          447866
# 2            no_offer   offering_to_receive         NaN          335999
# 3           reception  receiving_possession     kickoff          335999
# 4  possession_outcome    possession_outcome         NaN          447866
#
#   from_player_name  from_player_shirt_number  to_player_id   to_player_name  \
# 0             GAVI                         9           NaN              NaN
# 1             GAVI                         9      335999.0  AYMERIC LAPORTE
# 2  AYMERIC LAPORTE                        24           NaN              NaN
# 3  AYMERIC LAPORTE                        24           NaN              NaN
# 4             GAVI                         9           NaN              NaN
#
#    to_player_shirt_number  team_id team_name sequence_type  \
# 0                     NaN    43969     SPAIN           NaN
# 1                    24.0    43969     SPAIN           NaN
# 2                     NaN    43969     SPAIN           NaN
# 3                     NaN    43969     SPAIN           NaN
# 4                     NaN    43969     SPAIN    possession
#
#                outcome outcome_additional opposition_touch   body_type  \
# 0                  NaN                NaN              NaN         NaN
# 1  possession_complete                NaN              NaN  right_foot
# 2                  NaN                NaN              NaN         NaN
# 3                  NaN                NaN              NaN         NaN
# 4  possession_complete                NaN              NaN         NaN
#
#   direction     pressure style style_additional frame_location game_state  \
# 0       NaN          NaN   NaN              NaN            NaN        NaN
# 1       NaN  no_pressure  push              NaN            NaN        NaN
# 2       NaN          NaN   NaN              NaN            NaN        NaN
# 3       NaN  no_pressure   NaN              NaN            NaN        NaN
# 4       NaN          NaN   NaN              NaN            NaN        NaN
#
#   origin origin_additional save_type save_detail stance  x_frame  y_frame  \
# 0    NaN               NaN       NaN         NaN    NaN      NaN      NaN
# 1    NaN               NaN       NaN         NaN    NaN      NaN      NaN
# 2    NaN               NaN       NaN         NaN    NaN      NaN      NaN
# 3    NaN               NaN       NaN         NaN    NaN      NaN      NaN
# 4    NaN               NaN       NaN         NaN    NaN      NaN      NaN
#
#       movement  offering_to_receive_total_units line_break_direction  \
# 0          NaN                              NaN                  NaN
# 1          NaN                              NaN                  NaN
# 2  no_movement                              3.0                  NaN
# 3          NaN                              NaN                  NaN
# 4          NaN                              NaN                  NaN
#
#   line_break_outcome team_shape team_unit team_units_broken  total_team_units  \
# 0                NaN        NaN       NaN               NaN               NaN
# 1      no_line_break        NaN       NaN               NaN               NaN
# 2                NaN        NaN       NaN               NaN               NaN
# 3                NaN     inside  in_front               NaN               3.0
# 4                NaN        NaN       NaN               NaN               NaN
#
#    event_end_time_in_ms         x  x_mirrored         y  y_mirrored  \
# 0                   NaN  0.499810    0.499810  0.503971    0.503971
# 1                   NaN  0.499810    0.499810  0.503971    0.503971
# 2                1480.0  0.691905    0.308095  0.428824    0.571176
# 3                   NaN  0.691905    0.308095  0.428824    0.571176
# 4                   NaN  0.690286    0.309714  0.433382    0.566618
#
#    x_location_start  x_location_start_mirrored  x_location_end  \
# 0               NaN                        NaN             NaN
# 1           0.49981                    0.49981        0.690286
# 2               NaN                        NaN             NaN
# 3               NaN                        NaN             NaN
# 4               NaN                        NaN             NaN
#
#    x_location_end_mirrored  y_location_start  y_location_start_mirrored  \
# 0                      NaN               NaN                        NaN
# 1                 0.309714          0.503971                   0.503971
# 2                      NaN               NaN                        NaN
# 3                      NaN               NaN                        NaN
# 4                      NaN               NaN                        NaN
#
#    y_location_end  y_location_end_mirrored  match_time_in_min
# 0             NaN                      NaN                  0
# 1        0.433382                 0.566618                  0
# 2             NaN                      NaN                  0
# 3             NaN                      NaN                  0
# 4             NaN                      NaN                  0

# %%
df_est.head()
# Out:
#    match_id        team  corners  faltas_lanzadas  faltas_directas_lanzadas  \
# 0    133004       SPAIN        5               18                        12
# 1    133004  COSTA RICA        0               11                         8
# 2    133021       SPAIN        6               16                        14
# 3    133021     GERMANY        5               15                        13
# 4    133035       SPAIN        2               11                         9
#
#    faltas_realizadas  penaltis  penaltis_marcados %_acierto_penaltis  \
# 0                 11         1                  1                100
# 1                 18         0                  0               none
# 2                 15         0                  0               none
# 3                 16         0                  0               none
# 4                  8         0                  0               none
#
#    saques_banda  saques_banda_recepcionados  %_acierto_sb  ofrecimientos  \
# 0            24                          24         100.0           1677
# 1            13                          11          84.6            409
# 2            23                          21          91.3           1040
# 3            15                           8          53.3            670
# 4            22                          20          90.9           1747
#
#    ofrecimientos_con_movimiento  ofrecimientos_con_movimiento_camp_contr  \
# 0                          1085                                      694
# 1                           250                                      103
# 2                           633                                      282
# 3                           440                                      209
# 4                          1138                                      825
#
#    ofrecimientos_con_movimiento_ult_terc  remates_totales  remates_totales_fa  \
# 0                                    309               17                   3
# 1                                     43                0                   0
# 2                                    112                7                   2
# 3                                    107               10                   3
# 4                                    451               14                   7
#
#    remates_on_target  remates_on_target_fa  remates_off_target  \
# 0                  7                     0                   8
# 1                  0                     0                   8
# 2                  3                     1                   2
# 3                  4                     0                   2
# 4                  5                     1                   2
#
#    %_remates_on_target  goles  goles_fa  %_gol/on_target  goles_concedidos  \
# 0                 41.2      7         0            100.0                 0
# 1                  0.0      0         0              0.0                 7
# 2                 42.9      1         0             33.3                 1
# 3                 40.0      1         0             25.0                 1
# 4                 35.7      1         0             20.0                 2
#
#    centros_totales  centros_completados  asistencias_centro  pases  \
# 0               17                    2                   2   1037
# 1                5                    0                   0    218
# 2                9                    2                   1    624
# 3               13                    1                   0    337
# 4               20                    2                   0   1048
#
#    pases_completados  %_acierto_pases  pases_completados_linebreak  \
# 0                976             94.1                          193
# 1                159             72.9                           43
# 2                542             86.9                          118
# 3                270             80.1                           63
# 4                969             92.5                          126
#
#    asistencias_pase  cambios_de_juego  pases_ultimo_tercio  \
# 0                 2                 8                  203
# 1                 0                 1                   21
# 2                 0                 9                   69
# 3                 0                 2                   53
# 4                 1                 8                  244
#
#    pases_completados_ultimo_tercio  progresiones  intentos_regate  \
# 0                              180            42               11
# 1                               16             9                4
# 2                               55            31               11
# 3                               30            30                9
# 4                              218            25               10
#
#    intentos_regate_ult_terc  regates_completados  \
# 0                         9                    2
# 1                         2                    2
# 2                         5                    1
# 3                         4                    4
# 4                         6                    6
#
#    regates_completados_ult_terc  recepciones  recep_behind  recep_3_4  \
# 0                             2         1092            23          0
# 1                             1          226             1          1
# 2                             0          666            16          3
# 3                             1          379             9          2
# 4                             3         1092            17          0
#
#    recep_2_3  recep_1_2  recep_inside  %_recep_inside  recep_outside  \
# 0         60        307           628            57.5            464
# 1         23         74           139            61.5             87
# 2         47        186           362            54.4            304
# 3         34        132           246            64.9            133
# 4         18        193           674            61.7            418
#
#    %_recep_outside  recep_ultimo_tercio  bloqueos  despejes  intercepciones  \
# 0             42.5                  232        16        10               4
# 1             38.5                   31        21        30               8
# 2             45.6                   92        24        28               6
# 3             35.1                   82        32        24               8
# 4             38.3                  282         7        15              11
#
#    entradas_totales  entradas_exitosas  %_entradas_exitosas  take_on_against  \
# 0                18                  7                 38.9                4
# 1                42                 13                 31.0               11
# 2                40                 13                 32.5                9
# 3                45                 14                 31.1               11
# 4                16                  8                 50.0                4
#
#    pushing-on  presiones  presiones_directas  %_presion_directa  \
# 0         208        185                  50               27.0
# 1         795        585                  47                8.0
# 2         316        275                  45               16.4
# 3         508        387                  59               15.2
# 4         173        150                  25               16.7
#
#    gk_active_eng  gk_aerial_control  gk_def_support  gk_goalprevention_tot  \
# 0              3                  1               1                      0
# 1              7                  0               7                     17
# 2              5                  4               3                     11
# 3              3                  0               2                      7
# 4              1                  0               1                      6
#
#    gk_goalprevention_tot_saved  duelos_totales  duelos_totales_ganados  \
# 0                            0              37                      19
# 1                           10              37                      18
# 2                            9              33                      16
# 3                            6              36                      18
# 4                            4              30                      13
#
#    %_duelos_totales_ganados  duelos_campo_ganados  duelos_físicos_ganados  \
# 0                        51                     6                       2
# 1                        49                     1                       1
# 2                        48                     6                       1
# 3                        50                     8                       1
# 4                        43                     3                       0
#
#    duelos_aereos_ganados  sustituciones  posesion  posesión_disputa  \
# 0                     11              5     78.81              1.96
# 1                     16              5     19.23              1.96
# 2                      9              4     60.23              2.17
# 3                      9              5     37.60              2.17
# 4                     10              5     78.95              1.58
#
#    pases_verticales  pases_adelante  pases_atras  pases_horizontales  \
# 0                87             153          136                 687
# 1                22              37           27                  95
# 2                53              98           88                 356
# 3                35              59           42                 169
# 4                59             123          123                 723
#
#    %_pases_verticales  %_pases_adelante  %_pases_atras  %_pases_horizontales  \
# 0                   9                16             14                    70
# 1                  14                23             17                    60
# 2                  10                18             16                    66
# 3                  13                22             16                    63
# 4                   6                13             13                    75
#
#    recuperaciones  recuperaciones_campo_contr  %_recuperaciones_campo_contr  \
# 0              38                          18                            47
# 1              38                           7                            18
# 2              47                          13                            28
# 3              48                          15                            31
# 4              35                          11                            31
#
#    recuperaciones_campo_prop  %_recuperaciones_campo_prop  recuperaciones1  \
# 0                         20                           53               47
# 1                         31                           82               39
# 2                         34                           72               50
# 3                         33                           69               53
# 4                         24                           69               35
#
#    recuperaciones_campo_contr1  %_recuperaciones_campo_contr1  \
# 0                           20                             43
# 1                            7                             18
# 2                           15                             30
# 3                           16                             30
# 4                           11                             31
#
#    recuperaciones_campo_prop1  %_recuperaciones_campo_prop1  perdidas  \
# 0                          27                            57       116
# 1                          32                            82       104
# 2                          35                            70       139
# 3                          37                            70       128
# 4                          24                            69       128
#
#    perdidas_campo_prop  %_perdidas_campo_prop  tarj_amarillas  tarjetas_rojas  \
# 0                   26                     22               0               0
# 1                   42                     40               2               0
# 2                   62                     45               1               0
# 3                   32                     25               3               0
# 4                   19                     15               0               0
#
#    asistencias_totales   xG  distancia_recorrida_km  n_speed_runs_(15-20km/h)  \
# 0                    4  3.5               122.43399                      1331
# 1                    0  0.0               116.61037                      1455
# 2                    1  0.6               112.65189                      1461
# 3                    0  1.3               115.54569                      1559
# 4                    1  1.4               114.04544                      1326
#
#    n_of_sprints_(>20km/h)  total_average_speed_(km/h)
# 0                     548                    6.720440
# 1                     453                    6.505847
# 2                     557                    6.504642
# 3                     617                    6.681131
# 4                     459                    6.558801

# %%
df_pl.to_sql(name='players', con=cursor, if_exists='replace', index=False)
df_te.to_sql(name='teams', con=cursor, if_exists='replace', index=False)
df_ma.to_sql(name='matches', con=cursor, if_exists='replace', index=False)
df_ev.to_sql(name='events', con=cursor, if_exists='replace', index=False)
df_est.to_sql(name='metricas', con=cursor, if_exists='replace', index=False)
# Out:
# 8

# %% [markdown]
# ### Tiramos algunas Queries para comprobar el correcto funcionamiento de la DB

# %%
#1 CUÁNTOS PASES HA HABIDO EN EL PARTIDO?
pd.read_sql('''

SELECT T.TEAM_ID, T.TEAM_NAME, COUNT(E.EVENT) AS TOTAL_PASSES
FROM TEAMS AS T
LEFT JOIN EVENTS AS E
ON T.TEAM_ID = E.TEAM_ID
WHERE E.EVENT = 'pass'
GROUP BY TEAM_NAME


''', cursor)
# Out:
#    TEAM_ID   TEAM_NAME  TOTAL_PASSES
# 0    43969       Spain          3717
# 1    43901  Costa Rica           218
# 2    43948     Germany           337
# 3    43819       Japan           214
# 4    43872     Morocco           294

# %%
#1 CUÁNTOS GOLES HA HABIDO EN EL PARTIDO?
pd.read_sql('''

SELECT T.TEAM_ID, T.TEAM_NAME, COUNT(E.EVENT) AS TOTAL_GOALS
FROM TEAMS AS T
LEFT JOIN EVENTS AS E
ON T.TEAM_ID = E.TEAM_ID
WHERE E.EVENT = 'goal'
GROUP BY TEAM_NAME


''', cursor)
# Out:
#    TEAM_ID TEAM_NAME  TOTAL_GOALS
# 0    43969     Spain            9
# 1    43948   Germany            1
# 2    43819     Japan            2
# 3    43872   Morocco            3

# %%
#df_pl.to_excel(r'C:\Users\david\Proyectos\QATAR 2022\PROYECTO ESPAÑA\repositorio\viz\ficheros Tableau\players.xlsx', index=False)
#df_te.to_excel(r'C:\Users\david\Proyectos\QATAR 2022\PROYECTO ESPAÑA\repositorio\viz\ficheros Tableau\teams.xlsx', index=False)
#df_ma.to_excel(r'C:\Users\david\Proyectos\QATAR 2022\PROYECTO ESPAÑA\repositorio\viz\ficheros Tableau\matches.xlsx', index=False)
##df_ev.to_excel(r'C:\Users\david\Proyectos\QATAR 2022\viz\eventa.xlsx', index=False)
